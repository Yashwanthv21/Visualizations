# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('gdp.csv')

# %%
df.head()
# Out:
#   Financial Year  Gross Domestic Product (in Rs. Cr) at 2004-05 Prices  \
# 0        1951-52                                             286147
# 1        1952-53                                             294267
# 2        1953-54                                             312177
# 3        1954-55                                             325431
# 4        1955-56                                             333766
#
#    Agriculture & Allied Services (in Rs. Cr.) at 2004-05 Prices  \
# 0                                             147216
# 1                                             151859
# 2                                             163553
# 3                                             168361
# 4                                             166906
#
#    Agriculture (in Rs. Cr.) at 2004-05 Prices  \
# 0                                      118877
# 1                                      123822
# 2                                      134958
# ...

# %%
cols = list(df.columns)
df = df[[cols[0], cols[2], cols[3], cols[4], cols[5], cols[6], cols[7]]]

# %%
n_frames = 500

rows = []
for i in range(len(df)-1):
    r1 = df.iloc[i].tolist()
    r2 = df.iloc[i+1].tolist()
    year = r1[0]
    temp = []
    for j in range(1, len(r1)):
        diff = (r2[j] - r1[j])/n_frames
        ss = [r1[j] + idx*diff  for idx in range(n_frames)]
        temp.append(ss)
#         print(len(ss))
        
    temp = np.array(temp)
    temp = temp.T.tolist()
    
    for e in temp:
        e.insert(0, year)
        
    rows.extend(temp)
    rows.append(r2)

# %%
dd = pd.DataFrame(rows, columns = df.columns)
dd.head()
# Out:
#   Financial Year  \
# 0        1951-52
# 1        1951-52
# 2        1951-52
# 3        1951-52
# 4        1951-52
#
#    Agriculture & Allied Services (in Rs. Cr.) at 2004-05 Prices  \
# 0                                         147216.000
# 1                                         147225.286
# 2                                         147234.572
# 3                                         147243.858
# 4                                         147253.144
#
#    Agriculture (in Rs. Cr.) at 2004-05 Prices  \
# 0                                   118877.00
# 1                                   118886.89
# 2                                   118896.78
# 3                                   118906.67
# 4                                   118916.56
#
#    Industry (in Rs. Cr.) at 2004-05 Prices  \
# 0                                47768.000
# 1                                47767.942
# 2                                47767.884
# 3                                47767.826
# ...

# %%
len(dd[dd['Financial Year'] == '1951-52'])
# Out:
# 500

# %%
dd.to_csv('ngdp.csv', index=False)
