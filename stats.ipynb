# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('gdp.csv')

# %%
df.head()
# Out:
#   Financial Year  Gross Domestic Product (in Rs. Cr) at 2004-05 Prices  \
# 0        1951-52                                             286147
# 1        1952-53                                             294267
# 2        1953-54                                             312177
# 3        1954-55                                             325431
# 4        1955-56                                             333766
#
#    Agriculture & Allied Services (in Rs. Cr.) at 2004-05 Prices  \
# 0                                             147216
# 1                                             151859
# 2                                             163553
# 3                                             168361
# 4                                             166906
#
#    Agriculture (in Rs. Cr.) at 2004-05 Prices  \
# 0                                      118877
# 1                                      123822
# 2                                      134958
# 3                                      138731
# 4                                      136679
#
#    Industry (in Rs. Cr.) at 2004-05 Prices  \
# 0                                    47768
# 1                                    47739
# 2                                    50409
# 3                                    54574
# 4                                    60311
#
#    Mining and Quarrying (in Rs. Cr.) at 2004-05 Prices  \
# 0                                               5772
# 1                                               5905
# 2                                               5993
# 3                                               6250
# 4                                               6348
#
#    Manufacturing (in Rs. Cr.) at 2004-05 Prices  \
# 0                                         25889
# 1                                         26789
# 2                                         28863
# 3                                         30885
# 4                                         33304
#
#    Services (in Rs. Cr.) at 2004-05 Prices  \
# 0                                    84799
# 1                                    87438
# 2                                    89940
# 3                                    94172
# 4                                    98845
#
#    Agri-culture & Allied Services -Share to Total GDP  \
# 0                                               5145
# 1                                               5161
# 2                                               5239
# 3                                               5173
# 4                                               5001
#
#    Agriculture - Share to Total GDP  ...  \
# 0                              4154  ...
# 1                              4208  ...
# 2                              4323  ...
# 3                              4263  ...
# 4                              4095  ...
#
#    Mining and Quarrying - Share to Total GDP  \
# 0                                        202
# 1                                        201
# 2                                        192
# 3                                        192
# 4                                        190
#
#    Manufacturing - Share to Total GDP  Services - Share to Total GDP  \
# 0                                 905                           2963
# 1                                 910                           2971
# 2                                 925                           2881
# 3                                 949                           2894
# 4                                 998                           2962
#
#    Gross Domestic Product - % Growth Rate (YoY)  \
# 0                                           233
# 1                                           284
# 2                                           609
# 3                                           425
# 4                                           256
#
#    Agri-culture & Allied Services - % Growth Rate (YoY)  \
# 0                                                149
# 1                                                315
# 2                                                770
# 3                                                294
# 4                                                -86
#
#    Agriculture - % Growth Rate (YoY)  Industry - % Growth Rate (YoY)  \
# 0                                164                             550
# 1                                416                              -6
# 2                                899                             559
# 3                                280                             826
# 4                               -148                            1051
#
#    Mining and Quarrying - % Growth Rate (YoY)  \
# 0                                        1233
# 1                                         231
# 2                                         150
# 3                                         428
# 4                                         158
#
#    Manufacturing - % Growth Rate (YoY)  Services - % Growth Rate (YoY)
# 0                                  316                             267
# 1                                  348                             311
# 2                                  774                             286
# 3                                  701                             471
# 4                                  783                             496
#
# [5 rows x 21 columns]

# %%
cols = list(df.columns)
df = df[[cols[0], cols[2], cols[3], cols[4], cols[5], cols[6], cols[7]]]

# %%
n_frames = 50

rows = []
for i in range(len(df)-1):
    r1 = df.iloc[i].tolist()
    r2 = df.iloc[i+1].tolist()
    year = r1[0]
    temp = []
    for j in range(1, len(r1)):
        diff = (r2[j] - r1[j])/n_frames
        ss = [r1[j] + idx*diff  for idx in range(n_frames)]
        temp.append(ss)
        print(len(ss))
        
    temp = np.array(temp)
    temp = temp.T.tolist()
    
    for e in temp:
        e.insert(0, year)
        
    rows.extend(temp)
    rows.append(r2)
# Out:
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50

# %%
dd = pd.DataFrame(rows, columns = df.columns)
dd.head()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~/opt/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/internals/construction.py in _list_to_arrays(data, columns, coerce_float, dtype)
#     499         result = _convert_object_array(
# --> 500             content, columns, dtype=dtype, coerce_float=coerce_float
#     501         )
#
# ~/opt/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/internals/construction.py in _convert_object_array(content, columns, coerce_float, dtype)
#     582                 "{col:d} columns passed, passed data had "
# --> 583                 "{con} columns".format(col=len(columns), con=len(content))
#     584             )
#
# AssertionError: 7 columns passed, passed data had 51 columns
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-3f8dcca84ae1> in <module>
# ----> 1 dd = pd.DataFrame(rows, columns = df.columns)
#       2 dd.head()
#
# ~/opt/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     448                     if is_named_tuple(data[0]) and columns is None:
#     449                         columns = data[0]._fields
# --> 450                     arrays, columns = to_arrays(data, columns, dtype=dtype)
#     451                     columns = ensure_index(columns)
#     452
#
# ~/opt/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/internals/construction.py in to_arrays(data, columns, coerce_float, dtype)
#     462         return [], []  # columns if columns is not None else []
#     463     if isinstance(data[0], (list, tuple)):
# --> 464         return _list_to_arrays(data, columns, coerce_float=coerce_float, dtype=dtype)
#     465     elif isinstance(data[0], abc.Mapping):
#     466         return _list_of_dict_to_arrays(
#
# ~/opt/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/internals/construction.py in _list_to_arrays(data, columns, coerce_float, dtype)
#     501         )
#     502     except AssertionError as e:
# --> 503         raise ValueError(e) from e
#     504     return result
#     505
#
# ValueError: 7 columns passed, passed data had 51 columns

# %%
.to_csv('ngdp.csv', index=False)
